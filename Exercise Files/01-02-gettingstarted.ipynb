# %% [markdown]
# <img src="https://prismic-io.s3.amazonaws.com/plotly-marketing-website/bd1f702a-b623-48ab-a459-3ee92a7499b4_logo-plotly.svg">
#
# ## Getting Stated with Plotly

# %% [markdown]
# ### Install Plotly
#
# Install with Pip
# `pip install plotly==4.12.0`
#
# -or-
#
# Install with Conda
# `conda install -c plotly plotly=4.12.0`

# %%
import plotly.express as px

# %% [markdown]
# ### Importing sample data from Plotly Express
#
# [The Data Package](https://plotly.com/python-api-reference/generated/plotly.express.data.html)

# %%
nz = px.data.gapminder().query("country == 'New Zealand'")
nz.head(3)
# Out:
# ---------------------------------------------------------------------------
# ColumnNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 nz = px.data.gapminder().query("country == 'New Zealand'")
#       2 nz.head(3)
#
# File D:\mcquerol Repos\files-data-visualizations-plotly-linkedin-course\.venv312\Lib\site-packages\plotly\data\__init__.py:68, in gapminder(datetimes, centroids, year, pretty_names, return_type)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File D:\mcquerol Repos\files-data-visualizations-plotly-linkedin-course\.venv312\Lib\site-packages\narwhals\dataframe.py:1612, in DataFrame.drop(self, strict, *columns)
#    1593 def drop(self, *columns: str | Iterable[str], strict: bool = True) -> Self:
#    1594     """Remove columns from the dataframe.
#    1595
#    1596     Arguments:
#    (...)   1610         1    2  7.0
#    1611     """
# -> 1612     return super().drop(*flatten(columns), strict=strict)
#
# File D:\mcquerol Repos\files-data-visualizations-plotly-linkedin-course\.venv312\Lib\site-packages\narwhals\dataframe.py:252, in BaseFrame.drop(self, strict, *columns)
#     251 def drop(self, *columns: Iterable[str], strict: bool) -> Self:
# --> 252     return self._with_compliant(self._compliant_frame.drop(columns, strict=strict))
#
# File D:\mcquerol Repos\files-data-visualizations-plotly-linkedin-course\.venv312\Lib\site-packages\narwhals\_pandas_like\dataframe.py:523, in PandasLikeDataFrame.drop(self, columns, strict)
#     522 def drop(self, columns: Sequence[str], *, strict: bool) -> Self:
# --> 523     to_drop = parse_columns_to_drop(self, columns, strict=strict)
#     524     return self._with_native(
#     525         self.native.drop(columns=to_drop), validate_column_names=False
#     526     )
#
# File D:\mcquerol Repos\files-data-visualizations-plotly-linkedin-course\.venv312\Lib\site-packages\narwhals\_utils.py:1276, in parse_columns_to_drop(frame, subset, strict)
#    1274 to_drop = list(subset)
#    1275 if error := check_columns_exist(to_drop, available=frame.columns):
# -> 1276     raise error
#    1277 return to_drop
#
# ColumnNotFoundError: The following columns were not found: ['centroid_lat', 'centroid_lon']
#
# Hint: Did you mean one of these columns: ['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap', 'iso_alpha', 'iso_num']?

# %% [markdown]
# ### Introducing the `Figure` in Plotly

# %%
#,title='New Zealand Population over Time'
fig = px.bar(nz, x='year', y='pop',title='New Zealand Population over Time')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 2
#       1 #,title='New Zealand Population over Time'
# ----> 2 fig = px.bar(nz, x='year', y='pop',title='New Zealand Population over Time')
#
# File D:\mcquerol Repos\files-data-visualizations-plotly-linkedin-course\.venv312\Lib\site-packages\plotly\express\_chart_types.py:381, in bar(data_frame, x, y, color, pattern_shape, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, hover_name, hover_data, custom_data, text, base, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, color_continuous_scale, pattern_shape_sequence, pattern_shape_map, range_color, color_continuous_midpoint, opacity, orientation, barmode, log_x, log_y, range_x, range_y, text_auto, title, subtitle, template, width, height)
#     332 def bar(
#     333     data_frame=None,
#     334     x=None,
#    (...)    375     height=None,
#     376 ) -> go.Figure:
#     377     """
#     378     In a bar plot, each row of `data_frame` is represented as a rectangular
#     379     mark.
#     380     """
# --> 381     return make_figure(
#     382         args=locals(),
#     383         constructor=go.Bar,
#     384         trace_patch=dict(textposition="auto"),
#     385         layout_patch=dict(barmode=barmode),
#     386     )
#
# File D:\mcquerol Repos\files-data-visualizations-plotly-linkedin-course\.venv312\Lib\site-packages\plotly\express\_core.py:1833, in make_figure(args, constructor, trace_patch, layout_patch)
#    1831 elif constructor in [go.Scatter, go.Funnel] + hist2d_types:
#    1832     args["x" if orient_v else "y"] = wide_cross_name
# -> 1833     args["y" if orient_v else "x"] = value_name
#    1834     if constructor != go.Histogram2d:
#    1835         args["color"] = args["color"] or var_name
#
# File D:\mcquerol Repos\files-data-visualizations-plotly-linkedin-course\.venv312\Lib\site-packages\plotly\express\_core.py:1773, in infer_config(args, constructor, trace_patch, layout_patch)
#    1766 # now that `df_output` exists and `args` contains only references, we complete
#    1767 # the special-case and wide-mode handling by further rewriting args and/or mutating
#    1768 # df_output
#    1770 count_name = _escape_col_name(df_output.columns, "count", [var_name, value_name])
#    1771 if not wide_mode and missing_bar_dim and constructor == go.Bar:
#    1772     # now that we've populated df_output, we check to see if the non-missing
# -> 1773     # dimension is categorical: if so, then setting the missing dimension to a
#    1774     # constant 1 is a less-insane thing to do than setting it to the index by
#    1775     # default and we let the normal auto-orientation-code do its thing later
#    1776     other_dim = "x" if missing_bar_dim == "y" else "y"
#    1777     if not _is_continuous(df_output, args[other_dim]):
#
# File D:\mcquerol Repos\files-data-visualizations-plotly-linkedin-course\.venv312\Lib\site-packages\plotly\express\_core.py:184, in make_mapping(args, variable)
#     182         msg = "Unexpected dtype, please report a bug"
#     183         raise ValueError(msg)
# --> 184 else:
#     185     msg = f"Expected Date or Datetime, got {dtype}"
#     186     raise TypeError(msg)
#
# AttributeError: 'NoneType' object has no attribute 'copy'

# %%
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="29534ada-f91d-4bcd-b874-176fbab78041" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("29534ada-f91d-4bcd-b874-176fbab78041")) {
#                     Plotly.newPlot(
#                         '29534ada-f91d-4bcd-b874-176fbab78041',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "year=%{x}<br>pop=%{y}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": [1952, 1957, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002, 2007], "xaxis": "x", "y": [1994794, 2229407, 2488550, 2728150, 2929100, 3164900, 3210650, 3317166, 3437674, 3676187, 3908037, 4115771], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpo ...

# %% [markdown]
# For more configuration help, visit: https://plotly.com/python/getting-started/
